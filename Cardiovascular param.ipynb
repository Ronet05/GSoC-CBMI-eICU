# %%
import pandas as pd
import numpy as np

# %%
infusiondrug=pd.read_csv("infusionDrug.csv")
infusiondrug.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    infusiondrugid  patientunitstayid  infusionoffset  \
# 0         1953469             242040             457
# 1         1998443             242082             425
# 2         1968206             242082             125
# 3         1991487             242082             665
# 4         1969910             242082              55
#
#                    drugname drugrate  infusionrate  drugamount  volumeoffluid  \
# 0    Milrinone (mcg/kg/min)      .43          11.8        20.0          100.0
# 1  Norepinephrine (mcg/min)    10.93          41.0         4.0          250.0
# 2  Norepinephrine (mcg/min)        7          26.3         4.0          250.0
# 3                NS (ml/hr)      200         200.0         NaN            NaN
# 4  Norepinephrine (mcg/min)     2.13           8.0         4.0          250.0
#
#    patientweight
# 0           91.7
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
infusiondrug.dtypes
# Out:
# infusiondrugid         int64
# patientunitstayid      int64
# infusionoffset         int64
# drugname              object
# drugrate              object
# infusionrate         float64
# drugamount           float64
# volumeoffluid        float64
# patientweight        float64
# dtype: object

# %%
inf_cpy=infusiondrug

# %%
infusiondrug['drugname']=infusiondrug['drugname'].astype('str')

# %%
any(infusiondrug['drugname'].isnull())
# Out:
# False

# %%
drug_names=infusiondrug['drugname'].unique()

# %%
for name in drug_names:
    if("Dobuta" in name):
        print(name)
# Out:
# Dobutamine (mcg/kg/min)
# Dobutamine (mcg/min)
# Dobutamine (ml/hr)
# Dobutamine
# Dobutamine ()
# Dobutamine (mcg/kg/hr)
# Dobutamine (units/min)

# %%
infusiondrug

# %%
infusiondrug=infusiondrug.loc[(infusiondrug['drugname'].str.contains("Dopamine")) | 
                              (infusiondrug['drugname'].str.contains("Norepinephrine")) | 
                              (infusiondrug['drugname'].str.contains("Epinephrine")) | 
                               (infusiondrug['drugname'].str.contains("norepinephrine")) | 
                               (infusiondrug['drugname'].str.contains("dopamine")) | 
                              (infusiondrug['drugname'].str.contains("Dobutamine"))]

# %%
infusiondrug
# Out:
#          infusiondrugid  patientunitstayid  infusionoffset  \
# 1               1998443             242082             425
# 2               1968206             242082             125
# 4               1969910             242082              55
# 9               1994217             242082             665
# 10              1985898             242082             230
# 11              1963880             242082            1265
# 12              1972141             242082             275
# 15              1968868             242319             301
# 16              1962842             242319              31
# 34              1965640             242505             846
# 35              2003496             242505            1941
# 36              2002150             242505            3056
# 37              1987547             242505            3248
# 38              2011465             242505            2454
# 39              1970368             242505            3232
# 40              1951507             242505            3791
# 41              1956357             242505            3433
# 42              1964511             242505            2925
# 43              1956956             242505            3649
# 44              2003686             242505            1004
# 45              1971211             242505            3151
# 46              1988552             242505             410
# 47              1961697             242505            3461
# 48              1962676             242505             100
# 49              2008863             242505            2675
# 50              1985448             242505            1722
# 51              1963544             242505             470
# 52              1974194             242505            1462
# 53              2015680             242505             634
# 54              2013213             242505            3126
# ...                 ...                ...             ...
# 4803542        75150536            3353251             763
# 4803550        75141235            3353251             833
# 4803586  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       28
# 4803592  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       10
# 4803616  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       30
# 4803628  Norepinephrine STD 4 mg Dextrose 5% 250 ml (mc...       25
# 4803629  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       15
# 4803632  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       30
# 4803635  Norepinephrine STD 4 mg Dextrose 5% 250 ml (mc...       15
# 4803641  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       14
# 4803645  Norepinephrine STD 4 mg Dextrose 5% 250 ml (mc...        5
# 4803649  Norepinephrine STD 4 mg Dextrose 5% 250 ml (mc...       10
# 4803654  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       12
# 4803657  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...        8
# 4803660  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       25
# 4803665  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...        9
# 4803668  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       13
# 4803670  Norepinephrine STD 4 mg Dextrose 5% 250 ml (mc...       20
# 4803673  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       11
# 4803678  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       25
# 4803681  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       16
# 4803694  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       16
# 4803716  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       12
#
#          infusionrate  drugamount  volumeoffluid  patientweight
# 1                41.0         4.0          250.0            NaN
# 2                26.3         4.0          250.0            NaN
# 4                 8.0         4.0          250.0            NaN
# 9                30.0         4.0          250.0            NaN
# 10               34.0         4.0          250.0            NaN
# 11               11.3         4.0          250.0            NaN
# 12               37.5         4.0          250.0            NaN
# 15                0.0         4.0          250.0            NaN
# 16               15.0         4.0          250.0            NaN
# 34                NaN         NaN            NaN            NaN
# 35                NaN         NaN            NaN            NaN
# 36                NaN         NaN            NaN            NaN
# 37                NaN         NaN            NaN            NaN
# 38                NaN         NaN            NaN            NaN
# 39                NaN         NaN            NaN            NaN
# 40                NaN         NaN            NaN            NaN
# 41                NaN         NaN            NaN            NaN
# 42                NaN         NaN            NaN            NaN
# 43                NaN         NaN            NaN            NaN
# 44                NaN         NaN            NaN            NaN
# 45                NaN         NaN            NaN            NaN
# 46                NaN         NaN            NaN            NaN
# 47                NaN         NaN            NaN            NaN
# 48                NaN         NaN            NaN            NaN
# 49                NaN         NaN            NaN            NaN
# 50                NaN         NaN            NaN            NaN
# 51                NaN         NaN            NaN            NaN
# 52                NaN         NaN            NaN            NaN
# 53                NaN         NaN            NaN            NaN
# 54                NaN         NaN            NaN            NaN
# ...               ...         ...            ...            ...
# 4803542           NaN         NaN            NaN            NaN
# 4803550           NaN         NaN            NaN            NaN
# 4803554           NaN         NaN            NaN            NaN
# 4803558           NaN         NaN            NaN            NaN
# 4803563           NaN         NaN            NaN            NaN
# 4803567           NaN         NaN            NaN            NaN
# 4803571           NaN         NaN            NaN            NaN
# 4803574           NaN         NaN            NaN            NaN
# 4803577           NaN         NaN            NaN            NaN
# 4803586           NaN         NaN            NaN            NaN
# 4803592           NaN         NaN            NaN            NaN
# 4803616           NaN         NaN            NaN            NaN
# 4803628           NaN         NaN            NaN            NaN
# 4803629           NaN         NaN            NaN            NaN
# 4803632           NaN         NaN            NaN            NaN
# 4803635           NaN         NaN            NaN            NaN
# 4803641           NaN         NaN            NaN            NaN
# 4803645           NaN         NaN            NaN            NaN
# 4803649           NaN         NaN            NaN            NaN
# 4803654           NaN         NaN            NaN            NaN
# 4803657           NaN         NaN            NaN            NaN
# 4803660           NaN         NaN            NaN            NaN
# 4803665           NaN         NaN            NaN            NaN
# 4803668           NaN         NaN            NaN            NaN
# 4803670           NaN         NaN            NaN            NaN
# 4803673           NaN         NaN            NaN            NaN
# 4803678           NaN         NaN            NaN            NaN
# 4803681           NaN         NaN            NaN            NaN
# 4803694           NaN         NaN            NaN            NaN
# 4803716           NaN         NaN            NaN            NaN
#
# [786703 rows x 9 columns]

# %%
import csv

# %%
infusiondrug.to_csv("cardiovascular_params.csv", sep=',', index=False, encoding='utf-8')

# %% [markdown]
# <h1>Continue from here</h1>

# %%
inf_drug=pd.read_csv('cardiovascular_params.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
inf_drug
# Out:
#         infusiondrugid  patientunitstayid  infusionoffset  \
# 0              1998443             242082             425
# 1              1968206             242082             125
# 2              1969910             242082              55
# 3              1994217             242082             665
# 4              1985898             242082             230
# 5              1963880             242082            1265
# 6              1972141             242082             275
# 7              1968868             242319             301
# 8              1962842             242319              31
# 9              1965640             242505             846
# 10             2003496             242505            1941
# 11             2002150             242505            3056
# 12             1987547             242505            3248
# 13             2011465             242505            2454
# 14             1970368             242505            3232
# 15             1951507             242505            3791
# 16             1956357             242505            3433
# 17             1964511             242505            2925
# 18             1956956             242505            3649
# 19             2003686             242505            1004
# 20             1971211             242505            3151
# 21             1988552             242505             410
# 22             1961697             242505            3461
# 23             1962676             242505             100
# 24             2008863             242505            2675
# 25             1985448             242505            1722
# 26             1963544             242505             470
# 27             1974194             242505            1462
# 28             2015680             242505             634
# 29             2013213             242505            3126
# ...                ...                ...             ...
# 786673        75150536            3353251             763
# 786674        75141235            3353251             833
# 786675        75185877            3353251             738
# 786676        75074723            3353251             803
# 786677        75060333            3353251            3763
# 786678        75071803            3353251             918
# 786679        75136520            3353251             853
# 786680        75192590            3353251             778
# 786681        75218324            3353251            2773
# 786682        75079513            3353251             748
# 786683        75148203            3353251            4358
# 786684        75218156            3353251             578
# 786685        75169617            3353251             393
# 786686        75117896            3353251            3163
# 786687        75071932            3353251             543
# 786688  Norepinephrine STD 4 mg Dextrose 5% 250 ml (mc...       15
# 786689  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       14
# 786690  Norepinephrine STD 4 mg Dextrose 5% 250 ml (mc...        5
# 786691  Norepinephrine STD 4 mg Dextrose 5% 250 ml (mc...       10
# 786692  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       12
# 786693  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...        8
# 786694  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       25
# 786695  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...        9
# 786696  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       13
# 786697  Norepinephrine STD 4 mg Dextrose 5% 250 ml (mc...       20
# 786698  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       11
# 786699  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       25
# 786700  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       16
# 786701  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       16
# 786702  Norepinephrine MAX 32 mg Dextrose 5% 250 ml (m...       12
#
#         infusionrate  drugamount  volumeoffluid  patientweight
# 0               41.0         4.0          250.0            NaN
# 1               26.3         4.0          250.0            NaN
# 2                8.0         4.0          250.0            NaN
# 3               30.0         4.0          250.0            NaN
# 4               34.0         4.0          250.0            NaN
# 5               11.3         4.0          250.0            NaN
# 6               37.5         4.0          250.0            NaN
# 7                0.0         4.0          250.0            NaN
# 8               15.0         4.0          250.0            NaN
# 9                NaN         NaN            NaN            NaN
# 10               NaN         NaN            NaN            NaN
# 11               NaN         NaN            NaN            NaN
# 12               NaN         NaN            NaN            NaN
# 13               NaN         NaN            NaN            NaN
# 14               NaN         NaN            NaN            NaN
# 15               NaN         NaN            NaN            NaN
# 16               NaN         NaN            NaN            NaN
# 17               NaN         NaN            NaN            NaN
# 18               NaN         NaN            NaN            NaN
# 19               NaN         NaN            NaN            NaN
# 20               NaN         NaN            NaN            NaN
# 21               NaN         NaN            NaN            NaN
# 22               NaN         NaN            NaN            NaN
# 23               NaN         NaN            NaN            NaN
# 24               NaN         NaN            NaN            NaN
# 25               NaN         NaN            NaN            NaN
# 26               NaN         NaN            NaN            NaN
# 27               NaN         NaN            NaN            NaN
# 28               NaN         NaN            NaN            NaN
# 29               NaN         NaN            NaN            NaN
# ...              ...         ...            ...            ...
# 786673           NaN         NaN            NaN            NaN
# 786674           NaN         NaN            NaN            NaN
# 786675           NaN         NaN            NaN            NaN
# 786676           NaN         NaN            NaN            NaN
# 786677           NaN         NaN            NaN            NaN
# 786678           NaN         NaN            NaN            NaN
# 786679           NaN         NaN            NaN            NaN
# 786680           NaN         NaN            NaN            NaN
# 786681           NaN         NaN            NaN            NaN
# 786682           NaN         NaN            NaN            NaN
# 786683           NaN         NaN            NaN            NaN
# 786684           NaN         NaN            NaN            NaN
# 786685           NaN         NaN            NaN            NaN
# 786686           NaN         NaN            NaN            NaN
# 786687           NaN         NaN            NaN            NaN
# 786688           NaN         NaN            NaN            NaN
# 786689           NaN         NaN            NaN            NaN
# 786690           NaN         NaN            NaN            NaN
# 786691           NaN         NaN            NaN            NaN
# 786692           NaN         NaN            NaN            NaN
# 786693           NaN         NaN            NaN            NaN
# 786694           NaN         NaN            NaN            NaN
# 786695           NaN         NaN            NaN            NaN
# 786696           NaN         NaN            NaN            NaN
# 786697           NaN         NaN            NaN            NaN
# 786698           NaN         NaN            NaN            NaN
# 786699           NaN         NaN            NaN            NaN
# 786700           NaN         NaN            NaN            NaN
# 786701           NaN         NaN            NaN            NaN
# 786702           NaN         NaN            NaN            NaN
#
# [786703 rows x 9 columns]

# %%
inf_drug_new=inf_drug.loc[inf_drug['drugname'].str.contains("\(")]

# %%
inf_drug_new['drugname'].unique()
# Out:
# array(['Norepinephrine (mcg/min)', 'Dopamine (mcg/kg/min)',
#        'Epinephrine (mcg/min)', 'Norepinephrine (ml/hr)',
#        'Norepinephrine ()', 'Dopamine (ml/hr)', 'Dobutamine (mcg/kg/min)',
#        'Norepinephrine (Unknown)', 'Norepinephrine (mcg/hr)',
#        'Norepinephrine (mcg/kg/min)', 'Norepinephrine (mg/hr)',
#        'Epinephrine (mcg/kg/min)', 'Epinephrine (ml/hr)',
#        'Norepinephrine (mcg/kg/hr)', 'Norepinephrine (mg/min)',
#        'Dobutamine (mcg/min)', 'Epinephrine (mcg/hr)', 'Dopamine ()',
#        'Dobutamine (ml/hr)', 'Dopamine (mcg/min)',
#        'dopamine (mcg/kg/min)', 'Epinephrine (mg/hr)',
#        'Epinephrine (mg/kg/min)', 'Dopamine (mcg/hr)',
#        'Norepinephrine (units/min)', 'Dobutamine ()',
#        'Dobutamine (mcg/kg/hr)', 'Dopamine (mg/hr)', 'Dopamine (Unknown)',
#        'Epinephrine ()', 'Dopamine (mcg/kg/hr)',
#        'Norepinephrine (mg/kg/min)', 'Dopamine (nanograms/kg/min)',
#        'norepinephrine Volume (ml) (ml/hr)', 'norepinephrine Volume (ml)',
#        'Dobutamine (units/min)',
#        'Norepinephrine STD 4 mg Dextrose 5% 250 ml (mcg/min)',
#        'Norepinephrine MAX 32 mg Dextrose 5% 250 ml (mcg/min)',
#        'Norepinephrine STD 8 mg Dextrose 5% 500 ml (mcg/min)',
#        'Norepinephrine STD 32 mg Dextrose 5% 500 ml (mcg/min)',
#        'Norepinephrine STD 4 mg Dextrose 5% 500 ml (mcg/min)',
#        'Norepinephrine MAX 32 mg Dextrose 5% 500 ml (mcg/min)',
#        'Norepinephrine STD 32 mg Dextrose 5% 282 ml (mcg/min)',
#        'Norepinephrine STD 8 mg Dextrose 5% 250 ml (mcg/min)'],
#       dtype=object)

# %%
# Out:
# True

# %%
vitalp=pd.read_csv("vitalPeriodic.csv",chunksize=100000)

# %%
vp_list=[]
for chunk in vitalp:
    vp_list.append(chunk)

# %%
df_vitalp=pd.concat(vp_list)

# %%
df_vitalp.head()
# Out:
#    patientunitstayid  observationoffset  temperature  heartrate  \
# 0             141168               2059          NaN       92.0
# 1             141168               1289          NaN      118.0
# 2             141168               1794          NaN       78.0
# 3             141168               1374          NaN      118.0
# 4             141168               2039          NaN       92.0
#
#    systemicsystolic  systemicdiastolic
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN

# %%
df_vitalp=df_vitalp[['patientunitstayid','observationoffset','temperature','heartrate','systemicsystolic','systemicdiastolic']]

# %%
df_vitalp.to_csv("systemicsystolic_measures.csv", sep=',', index=False,encoding='utf-8')

# %%
len(df_vitalp)
# Out:
# 146671642

# %%
patient=pd.read_csv('patient.csv')

# %%
patient.head()
# Out:
#    patientunitstayid  patienthealthsystemstayid  gender age  ethnicity  \
# 0             141168                     128919  Female  70  Caucasian
# 1             141178                     128927  Female  52  Caucasian
# 2             141179                     128927  Female  52  Caucasian
# 3             141194                     128941    Male  68  Caucasian
# 4             141196                     128943    Male  71  Caucasian
#
#    hospitalid  wardid                              apacheadmissiondx  \
# 0          59      91  Rhythm disturbance (atrial, supraventricular)
# 1          60      83                                            NaN
# 2          60      83                                            NaN
# 3          73      92          Sepsis, renal/UTI (including bladder)
# 4          67     109                                            NaN
#
#    admissionheight hospitaladmittime24  ...       unitadmitsource  \
# 0            152.4            15:54:00  ...          Direct Admit
# 1            162.6            08:56:00  ...  Emergency Department
# 2            162.6            08:56:00  ...            ICU to SDU
# 3            180.3            18:18:40  ...                 Floor
# 4            162.6            20:21:00  ...            ICU to SDU
#
#   unitvisitnumber    unitstaytype admissionweight  dischargeweight  \
# 0               1           admit            84.3             85.8
# 1               1           admit            54.4             54.4
# 2               2  stepdown/other             NaN             60.4
# 3               1           admit            73.9             76.7
# 4               2  stepdown/other             NaN             63.2
#
#   unitdischargetime24 unitdischargeoffset unitdischargelocation  \
# 0            03:50:00                3596                 Death
# 1            09:18:00                   8  Step-Down Unit (SDU)
# 2            19:20:00                2042                  Home
# 3            15:31:00                4813                 Floor
# 4            22:23:00                1463                 Floor
#
#   unitdischargestatus  uniquepid
# 0             Expired  002-34851
# 1               Alive  002-33870
# 2               Alive  002-33870
# 3               Alive   002-5276
# 4               Alive  002-37665
#
# [5 rows x 29 columns]

# %%
patient=patient[['patientunitstayid', 'admissionweight', 'dischargeweight', 'unitdischargeoffset']]

# %%
patient.head()
# Out:
#    patientunitstayid  admissionweight  dischargeweight  unitdischargeoffset
# 0             141168             84.3             85.8                 3596
# 1             141178             54.4             54.4                    8
# 2             141179              NaN             60.4                 2042
# 3             141194             73.9             76.7                 4813
# 4             141196              NaN             63.2                 1463

# %%
l='i am ronet swaminathan'

# %%
l.split(" ")
# Out:
# ['i', 'am', 'ronet', 'swaminathan']

# %%
l.split(",")[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-0b6f8c993936> in <module>
# ----> 1 l.split(",")[1]
#
# IndexError: list index out of range
