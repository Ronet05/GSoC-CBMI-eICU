# %%
import pandas as pd
import numpy as np

# %%
infusiondrug=pd.read_csv("infusionDrug.csv")
infusiondrug.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    infusiondrugid  patientunitstayid  infusionoffset  \
# 0         1953469             242040             457
# 1         1998443             242082             425
# 2         1968206             242082             125
# 3         1991487             242082             665
# 4         1969910             242082              55
#
#                    drugname drugrate  infusionrate  drugamount  volumeoffluid  \
# 0    Milrinone (mcg/kg/min)      .43          11.8        20.0          100.0
# 1  Norepinephrine (mcg/min)    10.93          41.0         4.0          250.0
# 2  Norepinephrine (mcg/min)        7          26.3         4.0          250.0
# 3                NS (ml/hr)      200         200.0         NaN            NaN
# 4  Norepinephrine (mcg/min)     2.13           8.0         4.0          250.0
#
#    patientweight
# 0           91.7
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
infusiondrug.dtypes
# Out:
# infusiondrugid         int64
# patientunitstayid      int64
# infusionoffset         int64
# drugname              object
# drugrate              object
# infusionrate         float64
# drugamount           float64
# volumeoffluid        float64
# patientweight        float64
# dtype: object

# %%
inf_cpy=infusiondrug

# %%
infusiondrug['drugname']=infusiondrug['drugname'].astype('str')

# %%
any(infusiondrug['drugname'].isnull())
# Out:
# False

# %%
drug_names=infusiondrug['drugname'].unique()

# %%
for name in drug_names:
    if("Dopamine" in name):
        print(name)
# Out:
# Dopamine (mcg/kg/min)
# Dopamine (ml/hr)
# Dopamine ()
# Dopamine (mcg/min)
# Dopamine
# Dopamine (mcg/hr)
# Dopamine (mg/hr)
# Dopamine (Unknown)
# Dopamine (mcg/kg/hr)
# Dopamine (nanograms/kg/min)

# %%
infusiondrug=infusiondrug.loc[(infusiondrug['drugname'].str.contains("Dopamine")) | (infusiondrug['drugname'].str.contains("Norepirephrine")) | (infusiondrug['drugname'].str.contains("Epinephrine"))]

# %%
infusiondrug
# Out:
#          infusiondrugid  patientunitstayid  infusionoffset  \
# 77              1985606             243026               4
# 119             1980047             243494              20
# 125             2012144             243494             873
# 126             2001711             243494             434
# 128             2008259             243494             443
# 129             2000724             243494             685
# 131             2008911             243494             775
# 269             1963580             245240            1029
# 271             1975230             245240             364
# 275             2014887             245240             489
# 281             1994273             245240             549
# 294             1965737             245240             789
# 298             1999918             245240             639
# 304             1968651             245240             609
# 377             1968776             245885            1669
# 379             2001276             245885            2629
# 380             1971271             245885            1009
# 381             1995567             245885            1429
# 382             1979414             245885            1909
# 383             2015270             245885             649
# 384             1988345             245885            2149
# 410             1984689             245956             233
# 419             2015119             245956              68
# 422             2004772             245956             263
# 424             1957538             245956               7
# 439             2015978             245984            1414
# 443             1990631             245984            1470
# 452        Dopamine (mcg/kg/min)        4           NaN         NaN
# 456        Dopamine (mcg/kg/min)        7           NaN         NaN
# 460             Dopamine (ml/hr)       UD           NaN         NaN
# ...                          ...      ...           ...         ...
# 4760615  Epinephrine (mg/kg/min)      0.6      236250.0         4.0
# 4760619  Epinephrine (mg/kg/min)      0.2       78750.0         4.0
# 4760622  Epinephrine (mg/kg/min)      0.2       78750.0         4.0
# 4760629  Epinephrine (mg/kg/min)     0.25       98437.5         4.0
# 4760630  Epinephrine (mg/kg/min)      0.3      118125.0         4.0
# 4760639  Epinephrine (mg/kg/min)      .15       59062.5         4.0
# 4760646  Epinephrine (mg/kg/min)      0.4      157500.0         4.0
# 4760806  Epinephrine (mg/kg/min)     0.15       46687.5         4.0
# 4760807  Epinephrine (mg/kg/min)      0.3       93375.0         4.0
# 4760995  Epinephrine (mg/kg/min)        0           0.0         4.0
# 4761000  Epinephrine (mg/kg/min)        0           0.0         4.0
# 4761014  Epinephrine (mg/kg/min)     0.14       54862.5         4.0
# 4761016  Epinephrine (mg/kg/min)        0           0.0         4.0
# 4761023  Epinephrine (mg/kg/min)        0           0.0         4.0
# 4761035  Epinephrine (mg/kg/min)        0           0.0         4.0
# 4761039  Epinephrine (mg/kg/min)     0.08       31350.0         4.0
# 4761040  Epinephrine (mg/kg/min)      0.1       39187.5         4.0
# 4761042  Epinephrine (mg/kg/min)     0.16       62700.0         4.0
# 4761703    Dopamine (mcg/kg/min)        0           0.0       400.0
# 4761706    Dopamine (mcg/kg/min)        0           0.0       400.0
# 4761707    Dopamine (mcg/kg/min)      6.9          24.0       400.0
# 4761710    Dopamine (mcg/kg/min)      0.5           1.7       400.0
# 4761712    Dopamine (mcg/kg/min)        2           7.0       400.0
# 4761715    Dopamine (mcg/kg/min)        2           7.0       400.0
# 4761728    Dopamine (mcg/kg/min)        0           0.0       400.0
# 4762101    Dopamine (mcg/kg/min)        8          18.1       400.0
# 4762102    Dopamine (mcg/kg/min)        8          18.1       400.0
# 4762103    Dopamine (mcg/kg/min)        4           9.0       400.0
# 4762104    Dopamine (mcg/kg/min)        9          20.4       400.0
# 4762105    Dopamine (mcg/kg/min)        5          11.3       400.0
#
#          volumeoffluid  patientweight
# 77               250.0          207.3
# 119                NaN            NaN
# 125                NaN            NaN
# 126                NaN            NaN
# 128                NaN            NaN
# 129                NaN            NaN
# 131                NaN            NaN
# 269              250.0            NaN
# 271              250.0            NaN
# 275              250.0            NaN
# 281              250.0            NaN
# 294              250.0            NaN
# 298              250.0            NaN
# 304              250.0            NaN
# 377              250.0          104.3
# 379              250.0          104.3
# 380              250.0          104.3
# 381              250.0          104.3
# 382              250.0          104.3
# 383              250.0          104.3
# 384              250.0          104.3
# 410                NaN            NaN
# 419                NaN            NaN
# 422                NaN            NaN
# 424                NaN            NaN
# 439                NaN            NaN
# 443                NaN            NaN
# 452                NaN            NaN
# 456                NaN            NaN
# 460                NaN            NaN
# ...                ...            ...
# 4760615          250.0          105.0
# 4760619          250.0          105.0
# 4760622          250.0          105.0
# 4760629          250.0          105.0
# 4760630          250.0          105.0
# 4760639          250.0          105.0
# 4760646          250.0          105.0
# 4760806          250.0           83.0
# 4760807          250.0           83.0
# 4760995          250.0          104.5
# 4761000          250.0          104.5
# 4761014          250.0          104.5
# 4761016          250.0          104.5
# 4761023          250.0          104.5
# 4761035          250.0          104.5
# 4761039          250.0          104.5
# 4761040          250.0          104.5
# 4761042          250.0          104.5
# 4761703          250.0           92.7
# 4761706          250.0           92.7
# 4761707          250.0           92.7
# 4761710          250.0           92.7
# 4761712          250.0           92.7
# 4761715          250.0           92.7
# 4761728          250.0           92.7
# 4762101          250.0           60.3
# 4762102          250.0           60.3
# 4762103          250.0           60.3
# 4762104          250.0           60.3
# 4762105          250.0           60.3
#
# [144153 rows x 9 columns]

# %%
import csv

# %%
infusiondrug.to_csv("cardiovascular_params.csv", sep=',', index=False, encoding='utf-8')

# %% [markdown]
# <h1>Continue from here</h1>

# %%
inf_drug=pd.read_csv('cardiovascular_params.csv')

# %%
inf_drug.head()
# Out:
#    infusiondrugid  patientunitstayid  infusionoffset               drugname  \
# 0         1985606             243026               4  Dopamine (mcg/kg/min)
# 1         1980047             243494              20  Epinephrine (mcg/min)
# 2         2012144             243494             873  Epinephrine (mcg/min)
# 3         2001711             243494             434  Dopamine (mcg/kg/min)
# 4         2008259             243494             443  Epinephrine (mcg/min)
#
#   drugrate  infusionrate  drugamount  volumeoffluid  patientweight
# 0        4          31.1       400.0          250.0          207.3
# 1       14           NaN         NaN            NaN            NaN
# 2        0           NaN         NaN            NaN            NaN
# 3        5           NaN         NaN            NaN            NaN
# 4       10           NaN         NaN            NaN            NaN

# %%
drug_names=inf_drug['drugname'].unique()

# %%
for name in drug_names:
    print(name)
# Out:
# Dopamine (mcg/kg/min)
# Epinephrine (mcg/min)
# Dopamine (ml/hr)
# Epinephrine (mcg/kg/min)
# Epinephrine (ml/hr)
# Epinephrine (mcg/hr)
# Dopamine ()
# Dopamine (mcg/min)
# Dopamine
# Epinephrine
# Epinephrine (mg/hr)
# Epinephrine (mg/kg/min)
# Dopamine (mcg/hr)
# Dopamine (mg/hr)
# Dopamine (Unknown)
# Epinephrine ()
# Dopamine (mcg/kg/hr)
# Dopamine (nanograms/kg/min)

# %%
any(inf_drug['drugrate'].isna())
# Out:
# True
